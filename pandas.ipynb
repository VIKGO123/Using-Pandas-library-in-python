# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv",skiprows=2)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv",header=2)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv",nrows=2)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv",na_values=["n.a.","not availiable"])
df
# Out:
#   tickers            eps  revenue   price         people
# 0   GOOGL          27.82       87   845.0     larry page
# 1     WMT           4.61      484    65.0            NaN
# 2    MSFT             -1       85    64.0     bill gates
# 3    RIL   not available       50  1023.0  mukesh ambani
# 4    TATA            5.6       -1     NaN     ratan tata

# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv("C:/Users\hp/Desktop/AI/data/stock_data.csv",na_values={'eps':['not availiable','n.a.'],'revenue':[-1],'people':['not availiable']})
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82     87.0   845     larry page
# 1     WMT           4.61    484.0    65           n.a.
# 2    MSFT             -1     85.0    64     bill gates
# 3    RIL   not available     50.0  1023  mukesh ambani
# 4    TATA            5.6      NaN  n.a.     ratan tata

# %%
df.to_csv("new.csv",index=False)

# %%
import xlrd
df=pd.read_excel("C:/Users/hp/Desktop/AI/data/stock_data.xlsx","Sheet1")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df_stocks=pd.DataFrame({'tickers':['google','wmt'],'price':[845,65],'pe':[30.27,14.26]})
df_weather=pd.DataFrame({'day':['1/1/2017','1/2/2017'],'temp':[32,35],'event':['rain','sunny']})
with pd.ExcelWriter('stocks_weather.xlsx')as writer:
    df_stocks.to_excel(writer,sheet_name="stocks")
    df_weather.to_excel(writer,sheet_name="weather")

# %%
import pandas as pd
df=pd.read_csv("C:/Users/hp/Desktop/AI/data/iris.csv")
df['Species'][df['Species']=='Iris-setosa'].val_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-d987c7d5d9d5> in <module>()
#       1 import pandas as pd
#       2 df=pd.read_csv("C:/Users/hp/Desktop/AI/data/iris.csv")
# ----> 3 df['Species'][df['Species']=='Iris-setosa'].val_count
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'val_count'

# %%
df_stocks=pd.DataFrame({'tickers':['google','wmt'],'price':[845,65],'pe':[30.27,14.26]})
df_weather=pd.DataFrame({'day':['1/1/2017','1/2/2017'],'temp':[32,35],'event':['rain','sunny']})
df_stocks
# Out:
#   tickers  price     pe
# 0  google    845  30.27
# 1     wmt     65  14.26

# %%
import pandas as pd
df=pd.read_csv("C:/Users/hp/Desktop/AI/data/iris.csv")
l=list(df['Species'].value_counts()) #using value_counts() in pandas to get no .of iterations of a cell-  
k=list(df['Species'].unique())# to get unique col values
data={'Species':k,'count':l}
    
df=pd.DataFrame(data,index=[1,2,3])
df
# Out:
#            Species  count
# 1      Iris-setosa     50
# 2  Iris-versicolor     50
# 3   Iris-virginica     50

# %%
# Create an example dataframe
data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3]}
df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])
df
# Out:
#              name  year  reports
# Cochice     Jason  2012        4
# Pima        Molly  2012       24
# Santa Cruz   Tina  2013       31
# Maricopa     Jake  2014        2
# Yuma          Amy  2014        3

# %%
# Create an example dataframe
data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3]}
df = pd.DataFrame(data, index =[1,2,3,4,5])#index can't be bool
df
# Out:
#     name  year  reports
# 1  Jason  2012        4
# 2  Molly  2012       24
# 3   Tina  2013       31
# 4   Jake  2014        2
# 5    Amy  2014        3
